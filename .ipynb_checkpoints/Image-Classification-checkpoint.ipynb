# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress',     
              'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle','boot']

# %%
print(train_images.shape)
print(len(train_labels))
# Out:
# (60000, 28, 28)
# 60000

# %%
print(test_images.shape)
print(len(test_labels))
# Out:
# (10000, 28, 28)
# 10000

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)
])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1007 12:31:41.859672 23168 deprecation.py:506] From C:\Users\kalaa\Anaconda3\Annaconda\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(optimizer='adam',
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.5048 - acc: 0.8225
# Epoch 2/10
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.3745 - acc: 0.8658
# Epoch 3/10
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.3364 - acc: 0.8781
# Epoch 4/10
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.3150 - acc: 0.8857
# Epoch 5/10
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.2953 - acc: 0.8917
# Epoch 6/10
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.2791 - acc: 0.8957
# Epoch 7/10
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.2690 - acc: 0.8989
# Epoch 8/10
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.2592 - acc: 0.9028
# Epoch 9/10
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.2475 - acc: 0.9083
# Epoch 10/10
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.2404 - acc: 0.9107

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 10000/10000 - 0s - loss: 0.3520 - acc: 0.8827
#
# Test accuracy: 0.8827

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
predictions = probability_model.predict(test_images)
predictions[0]
# Out:
# array([6.4286751e-06, 3.8935230e-11, 8.6941903e-08, 7.2982753e-09,
#        1.2303977e-06, 1.2709904e-03, 4.2350935e-06, 4.3041915e-02,
#        2.7998075e-08, 9.5567507e-01], dtype=float32)

# %%
np.argmax(predictions[1])
# Out:
# 2
