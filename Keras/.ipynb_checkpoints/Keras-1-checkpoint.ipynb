# %% [markdown]
# #  Keras ML-project

# %%
# Importing numpy sub-lib, Sequential model and Dense NN layers from Keras 
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
#Loading the datasets
dataset = loadtxt('pima-indian-diabetes.csv', delimiter=',')

# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %%
#Exploring the data set
print("First patients first attribute : " + str(X[0][0]))
print("Last patients last attribute : " + str(X[767][7]))
print("First patients output : " + str(y[0]))
print("Last patients output : " + str(y[767]))
# Out:
# First patients first attribute : 6.0
# Last patients last attribute : 23.0
# First patients output : 1.0
# Last patients output : 0.0

# %%
#Defining the model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1216 13:46:00.937304 23936 deprecation_wrapper.py:119] From C:\Users\kalaa\Anaconda3\Annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1216 13:46:00.961239 23936 deprecation_wrapper.py:119] From C:\Users\kalaa\Anaconda3\Annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1216 13:46:00.966227 23936 deprecation_wrapper.py:119] From C:\Users\kalaa\Anaconda3\Annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# W1216 13:46:01.082083 23936 deprecation_wrapper.py:119] From C:\Users\kalaa\Anaconda3\Annaconda\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1216 13:46:01.132132 23936 deprecation_wrapper.py:119] From C:\Users\kalaa\Anaconda3\Annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W1216 13:46:01.145542 23936 deprecation.py:323] From C:\Users\kalaa\Anaconda3\Annaconda\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# W1216 13:46:01.463382 23936 deprecation_wrapper.py:119] From C:\Users\kalaa\Anaconda3\Annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/150
# 768/768 [==============================] - 1s 740us/step - loss: 2.8594 - acc: 0.5130
# Epoch 2/150
# 768/768 [==============================] - 0s 200us/step - loss: 1.9913 - acc: 0.4974
# Epoch 3/150
# 768/768 [==============================] - 0s 179us/step - loss: 1.5692 - acc: 0.5169
# Epoch 4/150
# 768/768 [==============================] - 0s 158us/step - loss: 1.2195 - acc: 0.5443
# Epoch 5/150
# 768/768 [==============================] - 0s 158us/step - loss: 0.9879 - acc: 0.5872
# Epoch 6/150
# 768/768 [==============================] - 0s 162us/step - loss: 0.9347 - acc: 0.5833
# Epoch 7/150
# 768/768 [==============================] - 0s 164us/step - loss: 0.8523 - acc: 0.6029
# Epoch 8/150
# ...

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 768/768 [==============================] - 0s 96us/step
# Accuracy: 75.00

# %%
predictions = model.predict_classes(X)
# summarize the first 5 cases
for i in range(5):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)

# %%
##Testing with differnt loss functions, optimizers and metrics

# %%
#Start with mean_squared_error

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 768/768 [==============================] - 0s 541us/step - loss: 0.1738 - acc: 0.7565
# Epoch 2/150
# 768/768 [==============================] - 0s 185us/step - loss: 0.1626 - acc: 0.7669
# Epoch 3/150
# 768/768 [==============================] - 0s 163us/step - loss: 0.1669 - acc: 0.7500
# Epoch 4/150
# 768/768 [==============================] - 0s 133us/step - loss: 0.1799 - acc: 0.7318
# Epoch 5/150
# 768/768 [==============================] - 0s 144us/step - loss: 0.1909 - acc: 0.7201
# Epoch 6/150
# 768/768 [==============================] - 0s 147us/step - loss: 0.1760 - acc: 0.7552
# Epoch 7/150
# 768/768 [==============================] - 0s 130us/step - loss: 0.1722 - acc: 0.7435
# Epoch 8/150
# 768/768 [==============================] - 0s 150us/step - loss: 0.1881 - acc: 0.7214
# Epoch 9/150
# 768/768 [==============================] - 0s 147us/step - loss: 0.1678 - acc: 0.7500
# Epoch 10/150
# ...

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 768/768 [==============================] - 0s 95us/step
# Accuracy: 77.99

# %%
predictions = model.predict_classes(X)
# summarize the first 5 cases
for i in range(5):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)

# %%
#Chaning the optimizer to sgd

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 768/768 [==============================] - 0s 503us/step - loss: 1.2589 - acc: 0.6406
# Epoch 2/150
# 768/768 [==============================] - 0s 141us/step - loss: 0.9022 - acc: 0.6523
# Epoch 3/150
# 768/768 [==============================] - 0s 148us/step - loss: 0.8521 - acc: 0.6536
# Epoch 4/150
# 768/768 [==============================] - 0s 154us/step - loss: 0.8097 - acc: 0.6536
# Epoch 5/150
# 768/768 [==============================] - 0s 159us/step - loss: 0.7745 - acc: 0.6536
# Epoch 6/150
# 768/768 [==============================] - 0s 147us/step - loss: 0.7446 - acc: 0.6536
# Epoch 7/150
# 768/768 [==============================] - 0s 135us/step - loss: 0.7207 - acc: 0.6536
# Epoch 8/150
# 768/768 [==============================] - 0s 165us/step - loss: 0.7002 - acc: 0.6536
# Epoch 9/150
# 768/768 [==============================] - 0s 200us/step - loss: 0.6868 - acc: 0.6536
# Epoch 10/150
# ...

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 768/768 [==============================] - 0s 117us/step
# Accuracy: 69.14

# %%
predictions = model.predict_classes(X)
# summarize the first 5 cases
for i in range(5):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)

# %%
#Chaning the optimizer to RMSprop

# %%
model.compile(loss='binary_crossentropy', optimizer='RMSprop', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 768/768 [==============================] - 0s 590us/step - loss: 0.5664 - acc: 0.6849
# Epoch 2/150
# 768/768 [==============================] - 0s 140us/step - loss: 0.5649 - acc: 0.6901
# Epoch 3/150
# 768/768 [==============================] - 0s 164us/step - loss: 0.5660 - acc: 0.6823
# Epoch 4/150
# 768/768 [==============================] - 0s 175us/step - loss: 0.5643 - acc: 0.6940
# Epoch 5/150
# 768/768 [==============================] - 0s 154us/step - loss: 0.5616 - acc: 0.6901
# Epoch 6/150
# 768/768 [==============================] - 0s 154us/step - loss: 0.5626 - acc: 0.6914
# Epoch 7/150
# 768/768 [==============================] - 0s 151us/step - loss: 0.5617 - acc: 0.6966
# Epoch 8/150
# 768/768 [==============================] - 0s 153us/step - loss: 0.5645 - acc: 0.7031
# Epoch 9/150
# 768/768 [==============================] - 0s 162us/step - loss: 0.5597 - acc: 0.7005
# Epoch 10/150
# ...

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 768/768 [==============================] - 0s 128us/step
# Accuracy: 73.96

# %%
predictions = model.predict_classes(X)
# summarize the first 5 cases
for i in range(5):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)

# %%
#Changing the optimizer to RMSprop and usiing mean_squared_error

# %%
model.compile(loss='mean_squared_error', optimizer='RMSprop', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 768/768 [==============================] - 0s 586us/step - loss: 0.1813 - acc: 0.7279
# Epoch 2/150
# 768/768 [==============================] - 0s 153us/step - loss: 0.1800 - acc: 0.7409
# Epoch 3/150
# 768/768 [==============================] - 0s 147us/step - loss: 0.1818 - acc: 0.7240
# Epoch 4/150
# 768/768 [==============================] - 0s 143us/step - loss: 0.1770 - acc: 0.7435
# Epoch 5/150
# 768/768 [==============================] - 0s 108us/step - loss: 0.1781 - acc: 0.7357
# Epoch 6/150
# 768/768 [==============================] - 0s 122us/step - loss: 0.1785 - acc: 0.7383
# Epoch 7/150
# 768/768 [==============================] - 0s 112us/step - loss: 0.1774 - acc: 0.7292
# Epoch 8/150
# 768/768 [==============================] - 0s 109us/step - loss: 0.1760 - acc: 0.7344
# Epoch 9/150
# 768/768 [==============================] - 0s 104us/step - loss: 0.1763 - acc: 0.7331
# Epoch 10/150
# ...

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 768/768 [==============================] - 0s 313us/step
# Accuracy: 75.91

# %%
predictions = model.predict_classes(X)
# summarize the first 5 cases
for i in range(5):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)

# %% [markdown]
# Using mean squared error with Adam optimizer for this data set gives the best results.
# (Need to look into working of keras methods and splitting of training & testing)
